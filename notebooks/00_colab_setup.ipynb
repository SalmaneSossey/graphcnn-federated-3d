# %% [markdown]
# # 00 - Colab Setup
#
# Starter setup for Google Colab T4 experiments.

# %%
# Replace the URL with your GitHub repository after the first push.
# !git clone https://github.com/SalmaneSossey/graphcnn-federated-3d.git
# %cd graphcnn-federated-3d

# %%
# !python -m pip install --upgrade pip
# !python -m pip install -r requirements-colab.txt

# %%
# !nvidia-smi

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
print('Device:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')
